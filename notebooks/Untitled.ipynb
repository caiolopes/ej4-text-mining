# %%
import pandas as pd

# %%
df = pd.read_csv("../processed/data.csv")

# %%
df_sample = df[:1000]
df_sample
# Out:
#       id              File  Class                   UF            Comarca  \
# 0      0  VAC0707577_1.txt      1             amazonas             manaus
# 1      1  VAC0578521_1.txt      0                  NaN                NaN
# 2      2  VAC0417737_1.txt      0    rio grande do sul    bento gonçalves
# 3      3  VAC1035213_1.txt      1               paraná           londrina
# 4      4  VAC0945721_1.txt      0                  NaN                NaN
# 5      5  VAC0978907_1.txt      0            são paulo              bauru
# 6      6  VAC0719063_1.txt      0                  NaN                NaN
# 7      7  VAC0992109_1.txt      0               paraná         guarapuava
# 8      8  VAC0942197_1.txt      1                  NaN                NaN
# 9      9  VAC0952104_1.txt      1            são paulo          guarulhos
# 10    10  VAC0864543_1.txt      1                  NaN                NaN
# 11    11  VAC0967959_1.txt      0                  NaN                NaN
# ...

# %%
data = df_sample["Date"]
data
# Out:
# 0       2015-1-13
# 1      2013-10-24
# 2        2013-7-5
# 3       2016-9-28
# 4             NaN
# 5       2015-10-9
# 6      2014-12-17
# 7       2016-1-14
# 8       2016-2-23
# 9       2015-6-26
# 10            NaN
# 11            NaN
# 12      2015-6-18
# 13       2016-8-9
# 14      2008-4-30
# 15     2014-12-18
# 16       2015-2-5
# 17      2016-9-12
# 18            NaN
# 19            NaN
# 20       2016-7-4
# 21            NaN
# 22      2016-12-5
# 23      2015-4-10
# 24      2015-3-13
# 25     2015-10-16
# 26            NaN
# 27            NaN
# 28            NaN
# 29            NaN
#           ...
# 970     2014-3-14
# 971     2015-5-19
# 972           NaN
# 973    2016-10-31
# 974           NaN
# 975    2006-12-14
# 976           NaN
# 977     2015-2-19
# 978           NaN
# 979     2017-5-23
# 980           NaN
# 981     2015-4-27
# 982     2016-6-13
# 983     2015-5-12
# 984     2016-3-17
# 985      2016-3-7
# 986     2000-3-31
# 987           NaN
# 988           NaN
# ...

# %%
class_sample = df_sample["Class"]

# %%
class_sample
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     0
# 12     0
# 13     0
# 14     1
# 15     1
# 16     1
# 17     1
# 18     1
# 19     0
# 20     1
# 21     0
# 22     1
# 23     0
# 24     0
# 25     1
# 26     0
# 27     0
# 28     0
# 29     0
#       ..
# 970    0
# 971    1
# 972    0
# 973    0
# 974    1
# 975    0
# 976    1
# 977    1
# 978    0
# 979    1
# 980    0
# 981    0
# 982    0
# 983    1
# 984    0
# 985    0
# 986    1
# 987    0
# 988    1
# 989    0
# 990    0
# 991    0
# 992    0
# 993    0
# 994    0
# 995    0
# 996    0
# 997    1
# 998    1
# 999    1
# Name: Class, Length: 1000, dtype: int64

# %%
freq = pd.DataFrame()
freq["class_sample"] =class_sample
freq["date"] =data
freq
# Out:
#      class_sample        date
# 0               1   2015-1-13
# 1               0  2013-10-24
# 2               0    2013-7-5
# 3               1   2016-9-28
# 4               0         NaN
# 5               0   2015-10-9
# 6               0  2014-12-17
# 7               0   2016-1-14
# 8               1   2016-2-23
# 9               1   2015-6-26
# 10              1         NaN
# 11              0         NaN
# 12              0   2015-6-18
# 13              0    2016-8-9
# 14              1   2008-4-30
# 15              1  2014-12-18
# 16              1    2015-2-5
# 17              1   2016-9-12
# 18              1         NaN
# 19              0         NaN
# 20              1    2016-7-4
# 21              0         NaN
# 22              1   2016-12-5
# 23              0   2015-4-10
# 24              0   2015-3-13
# 25              1  2015-10-16
# 26              0         NaN
# 27              0         NaN
# 28              0         NaN
# 29              0         NaN
# ...

# %%
df['Week/Year'] = df['Date'].apply(lambda x: "%d/%d" % (x.week, x.year))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-2744eb708a12> in <module>()
# ----> 1 df['Week/Year'] = df['Date'].apply(lambda x: "%d/%d" % (x.week, x.year))
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66645)()
#
# <ipython-input-26-2744eb708a12> in <lambda>(x)
# ----> 1 df['Week/Year'] = df['Date'].apply(lambda x: "%d/%d" % (x.week, x.year))
#
# AttributeError: 'str' object has no attribute 'week'
